# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_traffic = pd.read_csv('../data/web_traffic.csv')
df_traffic.head(5)
# Out:
#          date  sessions  unique_visitors  page_views  bounce_rate  \
# 0  2013-01-01      9760             7253       39093      0.00514
# 1  2013-01-02     10456             8151       47611      0.00406
# 2  2013-01-03     10076             7458       36963      0.00401
# 3  2013-01-04      9973             8063       53078      0.00562
# 4  2013-01-05     10223             7882       36790      0.00525
#
#    avg_session_duration_sec  traffic_source
# 0                     102.9  organic_search
# 1                     120.5  organic_search
# 2                     263.6          direct
# 3                     151.8          direct
# 4                     168.6        referral

# %%
least_bounce_rate = df_traffic.groupby('traffic_source')['bounce_rate'].mean().idxmin()
print(f"Nguồn truy cập có tỷ lệ thoát thấp nhất là: {least_bounce_rate}")
# Out:
# Nguồn truy cập có tỷ lệ thoát thấp nhất là: email_campaign

# %% [markdown]
# Choose email campaign, C

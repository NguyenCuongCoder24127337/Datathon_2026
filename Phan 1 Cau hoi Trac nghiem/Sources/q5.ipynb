# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_orderitems = pd.read_csv('../data/order_items.csv')
df_orderitems.head(5)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7976\2775633714.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_orderitems = pd.read_csv('../data/order_items.csv')
#    order_id  product_id  quantity  unit_price  discount_amount promo_id  \
# 0         1        2400         7     1138.22              0.0      NaN
# 1         2         609         7    10166.25              0.0      NaN
# 2         3         396         3    11220.33              0.0      NaN
# 3         4         635         5    10639.25              0.0      NaN
# 4         6        1935         1     1597.84              0.0      NaN
#
#   promo_id_2
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
non_promo_percent = df_orderitems['promo_id'].notnull().mean() * 100
print(f"Tỷ lệ đơn hàng không có mã khuyến mãi: {non_promo_percent:.2f}%")
# Out:
# Tỷ lệ đơn hàng không có mã khuyến mãi: 38.66%

# %% [markdown]
# Choose 39%, C

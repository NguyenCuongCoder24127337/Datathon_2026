# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_geo = pd.read_csv('../data/geography.csv')
df_orders = pd.read_csv('../data/orders.csv')
df_orderitems = pd.read_csv('../data/order_items.csv')
df_orderitems.info()
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714669 entries, 0 to 714668
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   order_id         714669 non-null  int64
#  1   product_id       714669 non-null  int64
#  2   quantity         714669 non-null  int64
#  3   unit_price       714669 non-null  float64
#  4   discount_amount  714669 non-null  float64
#  5   promo_id         276316 non-null  object
#  6   promo_id_2       206 non-null     object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 38.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646945 entries, 0 to 646944
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   order_id        646945 non-null  int64
#  1   order_date      646945 non-null  object
#  2   customer_id     646945 non-null  int64
#  3   zip             646945 non-null  int64
#  4   order_status    646945 non-null  object
#  5   payment_method  646945 non-null  object
#  6   device_type     646945 non-null  object
#  7   order_source    646945 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 39.5+ MB
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18284\2180656225.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_orderitems = pd.read_csv('../data/order_items.csv')

# %%
df_orderitems['revenue'] = df_orderitems['quantity'] * df_orderitems['unit_price']

df_merged = pd.merge(df_orders[['order_id', 'zip']], df_orderitems[['order_id', 'revenue']], on='order_id', how='inner')

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646945 entries, 0 to 646944
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   zip             646945 non-null  int64
#  1   city            646945 non-null  object
#  2   region          646945 non-null  object
#  3   district        646945 non-null  object
#  4   order_id        646945 non-null  int64
#  5   order_date      646945 non-null  object
#  6   customer_id     646945 non-null  int64
#  7   order_status    646945 non-null  object
#  8   payment_method  646945 non-null  object
#  9   device_type     646945 non-null  object
#  10  order_source    646945 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 54.3+ MB

# %%
df_merged = pd.merge(df_merged, df_geo[['zip', 'region']], on='zip', how='inner')

# %%
final_revenue = df_merged.groupby('region')['revenue'].sum()
print(final_revenue.idxmax())
# Out:
# East

# %% [markdown]
# Choose East, C

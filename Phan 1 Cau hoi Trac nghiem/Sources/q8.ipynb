# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df_orders = pd.read_csv('../data/orders.csv')
df_orders.head()
# Out:
#    order_id  order_date  customer_id   zip order_status payment_method  \
# 0         1  2012-07-04        58578  1109    delivered    credit_card
# 1         2  2012-07-04        58621  1330     returned            cod
# 2         3  2012-07-04        58811  1473    delivered    credit_card
# 3         4  2012-07-04        59453  2360    delivered    credit_card
# 4         6  2012-07-06        57821  2886    delivered         paypal
#
#   device_type    order_source
# 0     desktop     paid_search
# 1      mobile     paid_search
# 2     desktop          direct
# 3     desktop        referral
# 4      mobile  email_campaign

# %%
cancelled_orders = df_orders[df_orders['order_status'] == 'cancelled']
payment_counts = cancelled_orders['payment_method'].value_counts().idxmax()

print(f"Phương thức thanh toán bị hủy nhiều nhất là: {payment_counts}")
# Out:
# Phương thức thanh toán bị hủy nhiều nhất là: credit_card

# %% [markdown]
# Choose credit card A
